# %%
import pandas as pd
data = pd.read_csv("../data/spy/spy_2024_present.csv")
print(data.head())
# Out:
#         Price              Close                High                Low  \
# 0      Ticker                SPY                 SPY                SPY
# 1        Date                NaN                 NaN                NaN
# 2  2024-01-02  462.6103820800781  463.60873526144735  460.4962592993178
# 3  2024-01-03  458.8323669433594  461.18138219560745  458.2255412390415
# 4  2024-01-04  457.3544616699219   460.9562872853515  457.1293363679507
#
#                  Open     Volume
# 0                 SPY        SPY
# 1                 NaN        NaN
# 2  462.13079978352283  123623700
# 3   460.4375159158116  103585900
# 4   458.3527850038454   84232200
#          Price Close              High                Low               Open  \
# count      478   477               477                477                477
# unique     478   477               473                476                476
# top     Ticker   SPY  672.989990234375  662.1699829101562  666.8200073242188
# ...

# %%
print(data.describe())
# Out:
#          Price Close              High                Low               Open  \
# count      478   477               477                477                477
# unique     478   477               473                476                476
# top     Ticker   SPY  672.989990234375  662.1699829101562  666.8200073242188
# freq         1     1                 2                  2                  2
#
#        Volume
# count     477
# unique    477
# top       SPY
# freq        1

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   478 non-null    object
#  1   Close   477 non-null    object
#  2   High    477 non-null    object
#  3   Low     477 non-null    object
#  4   Open    477 non-null    object
#  5   Volume  477 non-null    object
# dtypes: object(6)
# memory usage: 22.5+ KB
# None
